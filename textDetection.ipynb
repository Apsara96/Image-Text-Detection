# %%
import pytesseract

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
img = cv2.imread('Demo.jpg')

# %%
plt.imshow(img)

# %%
img2char = pytesseract.image_to_string()
